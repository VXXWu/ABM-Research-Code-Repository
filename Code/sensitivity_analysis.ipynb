# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os.path import join

import warnings
warnings.filterwarnings(action='ignore')

from sklearn.preprocessing import StandardScaler

directory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
cambodia_file = r'Game Data\joinedDataCambodia.csv'
vietnam_file = r'Game Data\joinedDataVietnam.csv'
merged_file = r'Game Data\mergedData.csv'

sensitivity_folder=r'Sensitivity Analysis'
sensitivity_file = r'sensitivity_analysis_processed.csv'
sensitivity_results=r'Results'

clusters_folder="Clusters"
subsidy_max=10

cambodia_csv = pd.read_csv(os.path.join(directory, cambodia_file), engine="python")
vietnam_csv = pd.read_csv(os.path.join(directory, vietnam_file), engine='python')
merged_csv = pd.read_csv(os.path.join(directory, merged_file), engine='python')
sensitivity_csv = pd.read_csv(os.path.join(directory, sensitivity_folder, sensitivity_file), engine='python')

countries=['Vietnam', 'Cambodia']

metrics_title=['Income Per Patch',
 'Net Production Per Patch',
 'NCH Patches',
 'Non-HS Strategy Adoption',
 'Production Benefit Per NCH Patch',
 'Income Deviation',
 'HS Patches'
 ]

metrics=['Income Per Patch',
 'Net Production Per Patch',
 'NCH Patches (%)',
 'Non-HS Strategy Adoption (%)',
 'Production Benefit Per NCH Patch',
 'Income Deviation',
 'HS Patches (%)',]

metrics_extended =['Income Per Patch',
 'Net Production Per Patch',
 'NCH Patches',
 'Non-HS Strategy Adoption',
 'Production Benefit Per NCH Patch',
 'Income Deviation',
 'HS Patches',
 'Strategy Switches',
 'Switches to NCH Strategy',
 'Popular Strategy Adoption',
#  'HS Cells (Non-NCH Strategy)',
#  'HS Cells (NCH Strategy)',
 'NCH Patches (HS Strategy)',
 'NCH Patches (Non-HS Strategy)',
 'NCH Efficiency (HS Strategy)',
 'NCH Efficiency (Non-HS Strategy)',
 ]

metrics_extended_label =['Income Per Patch',
 'Net Production Per Patch',
 'NCH Patches (%)',
 'Non-HS Strategy Adoption (%)',
 'Production Benefit Per NCH Patch',
 'Income Deviation',
 'HS Patches (%)',
 'Strategy Switches',
 'Switches to NCH Strategy',
 'Popular Strategy Adoption (%)',
#  'HS Cells (Non-NCH Strategy)',
#  'HS Cells (NCH Strategy)',
 'NCH Patches (HS Strategy) (%)',
 'NCH Patches (Non-HS Strategy) (%)',
 'NCH Efficiency (HS Strategy)',
 'NCH Efficiency (Non-HS Strategy)',
 ]

set_percent_inds=[2, 3, 6, 9, 10, 11]

metrics_index=16

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
def to_percentage(x, pos):
    return f'{x * 100:.0f}%'
def to_percentage_decimal(x, pos):
    return f'{x * 100:.1f}%'

# %%
# standardizing all outcomes to z-score

outcomes_df=sensitivity_csv.iloc[:, 11:]
parameters_df=sensitivity_csv.iloc[:, :10]
outcomes_df.columns=metrics_title

import statsmodels.api as sm
from itertools import combinations

df=parameters_df
scaler = StandardScaler()
for column in range(len(df.columns)):
    df.iloc[:,column]=scaler.fit_transform(df.iloc[:,column].values.reshape(-1, 1))

# scaling outcomes to z-score
for column in outcomes_df.columns:
    scaler = StandardScaler()
    outcomes_df[column]=scaler.fit_transform(outcomes_df[column].values.reshape(-1, 1))
 
df = pd.DataFrame(parameters_df)

all_columns = df.columns  # Exclude the target variable column
for i in range(2, 3):
    for combination in combinations(all_columns, i):
        if len(combination) > 1:
            col_name = '*'.join(combination)
            df[col_name] = parameters_df[list(combination)].prod(axis=1)

            df[col_name]=scaler.fit_transform(df[col_name].values.reshape(-1, 1))


df = sm.add_constant(df)
coeff_dfs=[]

for column in outcomes_df.columns:
    y = outcomes_df[column].values
    model = sm.OLS(y, df).fit()

    print(model.summary())

    coefficients = model.params
    sorted_coefs = coefficients.reindex(coefficients.abs().sort_values(ascending=False).index)
    p_values = model.pvalues.reindex(sorted_coefs.index)

    temp_df=pd.DataFrame({'Coefficient': sorted_coefs, 'P-value': p_values})
    
    # include only p-value<0.1
    coeff_dfs.append(temp_df[temp_df['P-value'] < 0.1])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                 2.595e+04
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:15   Log-Likelihood:            -3.9119e+05
# No. Observations:              517000   AIC:                         7.825e+05
# Df Residuals:                  516944   BIC:                         7.831e+05
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             3.251e-15      0.001   4.53e-12      1.000      -0.001       0.001
# farmSize                             0.0884      0.001     93.388      0.000       0.087       0.090
# subsidy                              0.6727      0.001    937.979      0.000       0.671       0.674
# giniCoeff                            0.0268      0.001     33.503      0.000       0.025       0.028
# trustIndexMean                       0.0716      0.001     99.774      0.000       0.070       0.073
# carePatchMean                       -0.1184      0.001   -164.951      0.000      -0.120      -0.117
# careFarmerMean                       0.0642      0.001     89.426      0.000       0.063       0.066
# careOthersMean                       0.0250      0.001     34.875      0.000       0.024       0.026
# initialExperience                    0.2866      0.001    399.423      0.000       0.285       0.288
# nchPercent                           0.2644      0.001    368.471      0.000       0.263       0.266
# memory                              -0.0142      0.001    -19.725      0.000      -0.016      -0.013
# farmSize*subsidy                    -0.0220      0.001    -27.997      0.000      -0.023      -0.020
# farmSize*giniCoeff                   0.0149      0.001     15.724      0.000       0.013       0.017
# farmSize*trustIndexMean              0.0124      0.001     15.793      0.000       0.011       0.014
# farmSize*carePatchMean               0.0081      0.001     10.333      0.000       0.007       0.010
# farmSize*careFarmerMean              0.0010      0.001      1.335      0.182      -0.000       0.003
# farmSize*careOthersMean             -0.0032      0.001     -4.018      0.000      -0.005      -0.002
# farmSize*initialExperience           0.0005      0.001      0.653      0.514      -0.001       0.002
# farmSize*nchPercent                 -0.0042      0.001     -5.380      0.000      -0.006      -0.003
# farmSize*memory                     -0.0019      0.001     -2.400      0.016      -0.003      -0.000
# subsidy*giniCoeff                   -0.0013      0.001     -1.690      0.091      -0.003       0.000
# subsidy*trustIndexMean               0.0204      0.001     28.487      0.000       0.019       0.022
# subsidy*carePatchMean                0.0795      0.001    110.899      0.000       0.078       0.081
# subsidy*careFarmerMean              -0.0157      0.001    -21.909      0.000      -0.017      -0.014
# subsidy*careOthersMean              -0.0342      0.001    -47.675      0.000      -0.036      -0.033
# subsidy*initialExperience            0.0216      0.001     30.150      0.000       0.020       0.023
# subsidy*nchPercent                   0.1402      0.001    195.478      0.000       0.139       0.142
# subsidy*memory                       0.0079      0.001     10.959      0.000       0.006       0.009
# giniCoeff*trustIndexMean            -0.0003      0.001     -0.383      0.702      -0.002       0.001
# giniCoeff*carePatchMean              0.0045      0.001      5.671      0.000       0.003       0.006
# giniCoeff*careFarmerMean             0.0005      0.001      0.686      0.493      -0.001       0.002
# giniCoeff*careOthersMean            -0.0019      0.001     -2.402      0.016      -0.003      -0.000
# giniCoeff*initialExperience         -0.0095      0.001    -12.124      0.000      -0.011      -0.008
# giniCoeff*nchPercent                -0.0001      0.001     -0.187      0.852      -0.002       0.001
# giniCoeff*memory                    -0.0022      0.001     -2.817      0.005      -0.004      -0.001
# trustIndexMean*carePatchMean        -0.0042      0.001     -5.831      0.000      -0.006      -0.003
# trustIndexMean*careFarmerMean        0.0014      0.001      1.998      0.046    2.74e-05       0.003
# trustIndexMean*careOthersMean        0.0030      0.001      4.132      0.000       0.002       0.004
# trustIndexMean*initialExperience    -0.0260      0.001    -36.190      0.000      -0.027      -0.025
# trustIndexMean*nchPercent            0.0102      0.001     14.217      0.000       0.009       0.012
# trustIndexMean*memory               -0.0004      0.001     -0.583      0.560      -0.002       0.001
# carePatchMean*careFarmerMean        -0.0109      0.001    -15.145      0.000      -0.012      -0.009
# carePatchMean*careOthersMean         0.0014      0.001      1.890      0.059   -5.06e-05       0.003
# carePatchMean*initialExperience     -0.0046      0.001     -6.371      0.000      -0.006      -0.003
# carePatchMean*nchPercent            -0.0144      0.001    -19.995      0.000      -0.016      -0.013
# carePatchMean*memory                -0.0046      0.001     -6.402      0.000      -0.006      -0.003
# careFarmerMean*careOthersMean       -0.0158      0.001    -22.037      0.000      -0.017      -0.014
# careFarmerMean*initialExperience    -0.0057      0.001     -7.922      0.000      -0.007      -0.004
# careFarmerMean*nchPercent            0.0178      0.001     24.865      0.000       0.016       0.019
# careFarmerMean*memory                0.0013      0.001      1.835      0.066   -8.95e-05       0.003
# careOthersMean*initialExperience    -0.0065      0.001     -9.118      0.000      -0.008      -0.005
# careOthersMean*nchPercent            0.0147      0.001     20.417      0.000       0.013       0.016
# careOthersMean*memory                0.0028      0.001      3.903      0.000       0.001       0.004
# initialExperience*nchPercent        -0.2644      0.001   -368.396      0.000      -0.266      -0.263
# initialExperience*memory            -0.0024      0.001     -3.336      0.001      -0.004      -0.001
# nchPercent*memory                 8.884e-05      0.001      0.124      0.901      -0.001       0.001
# ==============================================================================
# Omnibus:                      950.705   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              986.649
# Skew:                           0.089   Prob(JB):                    5.65e-215
# Kurtosis:                       3.120   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     7454.
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:16   Log-Likelihood:            -5.8264e+05
# No. Observations:              517000   AIC:                         1.165e+06
# Df Residuals:                  516944   BIC:                         1.166e+06
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             6.704e-15      0.001   6.45e-12      1.000      -0.002       0.002
# farmSize                             0.1072      0.001     78.212      0.000       0.105       0.110
# subsidy                             -0.1249      0.001   -120.207      0.000      -0.127      -0.123
# giniCoeff                            0.0346      0.001     29.780      0.000       0.032       0.037
# trustIndexMean                       0.0912      0.001     87.720      0.000       0.089       0.093
# carePatchMean                       -0.1429      0.001   -137.486      0.000      -0.145      -0.141
# careFarmerMean                       0.0764      0.001     73.537      0.000       0.074       0.078
# careOthersMean                       0.0375      0.001     36.126      0.000       0.036       0.040
# initialExperience                    0.4014      0.001    386.336      0.000       0.399       0.403
# nchPercent                           0.2991      0.001    287.797      0.000       0.297       0.301
# memory                              -0.0158      0.001    -15.234      0.000      -0.018      -0.014
# farmSize*subsidy                    -0.0063      0.001     -5.567      0.000      -0.009      -0.004
# farmSize*giniCoeff                   0.0158      0.001     11.554      0.000       0.013       0.018
# farmSize*trustIndexMean              0.0137      0.001     12.064      0.000       0.012       0.016
# farmSize*carePatchMean               0.0151      0.001     13.297      0.000       0.013       0.017
# farmSize*careFarmerMean             -0.0060      0.001     -5.247      0.000      -0.008      -0.004
# farmSize*careOthersMean             -0.0053      0.001     -4.654      0.000      -0.008      -0.003
# farmSize*initialExperience          -0.0006      0.001     -0.507      0.612      -0.003       0.002
# farmSize*nchPercent                 -0.0107      0.001     -9.428      0.000      -0.013      -0.009
# farmSize*memory                     -0.0031      0.001     -2.694      0.007      -0.005      -0.001
# subsidy*giniCoeff                    0.0039      0.001      3.416      0.001       0.002       0.006
# subsidy*trustIndexMean               0.0286      0.001     27.548      0.000       0.027       0.031
# subsidy*carePatchMean                0.0074      0.001      7.125      0.000       0.005       0.009
# subsidy*careFarmerMean               0.0168      0.001     16.186      0.000       0.015       0.019
# subsidy*careOthersMean               0.0063      0.001      6.032      0.000       0.004       0.008
# subsidy*initialExperience           -0.0387      0.001    -37.227      0.000      -0.041      -0.037
# subsidy*nchPercent                   0.1895      0.001    182.393      0.000       0.187       0.192
# subsidy*memory                       0.0108      0.001     10.415      0.000       0.009       0.013
# giniCoeff*trustIndexMean            -0.0006      0.001     -0.497      0.619      -0.003       0.002
# giniCoeff*carePatchMean              0.0066      0.001      5.800      0.000       0.004       0.009
# giniCoeff*careFarmerMean            -0.0029      0.001     -2.547      0.011      -0.005      -0.001
# giniCoeff*careOthersMean            -0.0024      0.001     -2.106      0.035      -0.005      -0.000
# giniCoeff*initialExperience         -0.0106      0.001     -9.313      0.000      -0.013      -0.008
# giniCoeff*nchPercent                -0.0014      0.001     -1.256      0.209      -0.004       0.001
# giniCoeff*memory                    -0.0028      0.001     -2.438      0.015      -0.005      -0.001
# trustIndexMean*carePatchMean        -0.0053      0.001     -5.137      0.000      -0.007      -0.003
# trustIndexMean*careFarmerMean       -0.0002      0.001     -0.173      0.862      -0.002       0.002
# trustIndexMean*careOthersMean        0.0024      0.001      2.355      0.019       0.000       0.004
# trustIndexMean*initialExperience    -0.0291      0.001    -27.993      0.000      -0.031      -0.027
# trustIndexMean*nchPercent            0.0140      0.001     13.457      0.000       0.012       0.016
# trustIndexMean*memory               -0.0008      0.001     -0.816      0.415      -0.003       0.001
# carePatchMean*careFarmerMean        -0.0098      0.001     -9.468      0.000      -0.012      -0.008
# carePatchMean*careOthersMean         0.0079      0.001      7.611      0.000       0.006       0.010
# carePatchMean*initialExperience     -0.0034      0.001     -3.261      0.001      -0.005      -0.001
# carePatchMean*nchPercent             0.0089      0.001      8.603      0.000       0.007       0.011
# carePatchMean*memory                -0.0056      0.001     -5.367      0.000      -0.008      -0.004
# careFarmerMean*careOthersMean       -0.0229      0.001    -22.043      0.000      -0.025      -0.021
# careFarmerMean*initialExperience    -0.0053      0.001     -5.139      0.000      -0.007      -0.003
# careFarmerMean*nchPercent            0.0091      0.001      8.772      0.000       0.007       0.011
# careFarmerMean*memory                0.0016      0.001      1.530      0.126      -0.000       0.004
# careOthersMean*initialExperience    -0.0100      0.001     -9.577      0.000      -0.012      -0.008
# careOthersMean*nchPercent           -0.0016      0.001     -1.502      0.133      -0.004       0.000
# careOthersMean*memory                0.0035      0.001      3.354      0.001       0.001       0.006
# initialExperience*nchPercent        -0.3037      0.001   -292.244      0.000      -0.306      -0.302
# initialExperience*memory            -0.0002      0.001     -0.177      0.859      -0.002       0.002
# nchPercent*memory                    0.0013      0.001      1.240      0.215      -0.001       0.003
# ==============================================================================
# Omnibus:                    31280.754   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            54950.374
# Skew:                          -0.469   Prob(JB):                         0.00
# Kurtosis:                       4.292   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                 2.152e+04
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:18   Log-Likelihood:            -4.2581e+05
# No. Observations:              517000   AIC:                         8.517e+05
# Df Residuals:                  516944   BIC:                         8.523e+05
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             9.659e-14      0.001   1.26e-10      1.000      -0.002       0.002
# farmSize                             0.0352      0.001     34.811      0.000       0.033       0.037
# subsidy                              0.7469      0.001    973.974      0.000       0.745       0.748
# giniCoeff                            0.0043      0.001      5.017      0.000       0.003       0.006
# trustIndexMean                      -0.0009      0.001     -1.181      0.238      -0.002       0.001
# carePatchMean                       -0.1399      0.001   -182.354      0.000      -0.141      -0.138
# careFarmerMean                       0.0505      0.001     65.785      0.000       0.049       0.052
# careOthersMean                       0.0411      0.001     53.539      0.000       0.040       0.043
# initialExperience                   -0.1532      0.001   -199.759      0.000      -0.155      -0.152
# nchPercent                           0.0797      0.001    103.814      0.000       0.078       0.081
# memory                              -0.0023      0.001     -3.051      0.002      -0.004      -0.001
# farmSize*subsidy                    -0.0435      0.001    -51.842      0.000      -0.045      -0.042
# farmSize*giniCoeff                   0.0097      0.001      9.584      0.000       0.008       0.012
# farmSize*trustIndexMean              0.0023      0.001      2.724      0.006       0.001       0.004
# farmSize*carePatchMean              -0.0151      0.001    -17.976      0.000      -0.017      -0.013
# farmSize*careFarmerMean              0.0178      0.001     21.211      0.000       0.016       0.019
# farmSize*careOthersMean              0.0020      0.001      2.379      0.017       0.000       0.004
# farmSize*initialExperience          -0.0023      0.001     -2.705      0.007      -0.004      -0.001
# farmSize*nchPercent                  0.0072      0.001      8.604      0.000       0.006       0.009
# farmSize*memory                      0.0005      0.001      0.572      0.568      -0.001       0.002
# subsidy*giniCoeff                   -0.0113      0.001    -13.514      0.000      -0.013      -0.010
# subsidy*trustIndexMean              -0.0031      0.001     -4.036      0.000      -0.005      -0.002
# subsidy*carePatchMean                0.2091      0.001    272.624      0.000       0.208       0.211
# subsidy*careFarmerMean              -0.0702      0.001    -91.506      0.000      -0.072      -0.069
# subsidy*careOthersMean              -0.0819      0.001   -106.761      0.000      -0.083      -0.080
# subsidy*initialExperience            0.1235      0.001    161.044      0.000       0.122       0.125
# subsidy*nchPercent                  -0.0440      0.001    -57.302      0.000      -0.045      -0.042
# subsidy*memory                      -0.0014      0.001     -1.841      0.066      -0.003    9.12e-05
# giniCoeff*trustIndexMean             0.0003      0.001      0.359      0.720      -0.001       0.002
# giniCoeff*carePatchMean             -0.0019      0.001     -2.312      0.021      -0.004      -0.000
# giniCoeff*careFarmerMean             0.0070      0.001      8.339      0.000       0.005       0.009
# giniCoeff*careOthersMean            -0.0009      0.001     -1.125      0.261      -0.003       0.001
# giniCoeff*initialExperience         -0.0028      0.001     -3.295      0.001      -0.004      -0.001
# giniCoeff*nchPercent                 0.0019      0.001      2.255      0.024       0.000       0.004
# giniCoeff*memory                    -0.0004      0.001     -0.518      0.604      -0.002       0.001
# trustIndexMean*carePatchMean        -0.0010      0.001     -1.246      0.213      -0.002       0.001
# trustIndexMean*careFarmerMean        0.0025      0.001      3.298      0.001       0.001       0.004
# trustIndexMean*careOthersMean        0.0007      0.001      0.908      0.364      -0.001       0.002
# trustIndexMean*initialExperience    -0.0043      0.001     -5.612      0.000      -0.006      -0.003
# trustIndexMean*nchPercent           -0.0014      0.001     -1.785      0.074      -0.003       0.000
# trustIndexMean*memory                0.0013      0.001      1.686      0.092      -0.000       0.003
# carePatchMean*careFarmerMean        -0.0058      0.001     -7.516      0.000      -0.007      -0.004
# carePatchMean*careOthersMean        -0.0167      0.001    -21.728      0.000      -0.018      -0.015
# carePatchMean*initialExperience      0.0112      0.001     14.613      0.000       0.010       0.013
# carePatchMean*nchPercent            -0.0330      0.001    -43.048      0.000      -0.035      -0.032
# carePatchMean*memory              3.126e-05      0.001      0.041      0.967      -0.001       0.002
# careFarmerMean*careOthersMean       -0.0106      0.001    -13.786      0.000      -0.012      -0.009
# careFarmerMean*initialExperience    -0.0102      0.001    -13.333      0.000      -0.012      -0.009
# careFarmerMean*nchPercent            0.0172      0.001     22.472      0.000       0.016       0.019
# careFarmerMean*memory               -0.0001      0.001     -0.173      0.863      -0.002       0.001
# careOthersMean*initialExperience    -0.0166      0.001    -21.659      0.000      -0.018      -0.015
# careOthersMean*nchPercent            0.0272      0.001     35.439      0.000       0.026       0.029
# careOthersMean*memory               -0.0001      0.001     -0.133      0.894      -0.002       0.001
# initialExperience*nchPercent        -0.0788      0.001   -102.635      0.000      -0.080      -0.077
# initialExperience*memory            -0.0036      0.001     -4.659      0.000      -0.005      -0.002
# nchPercent*memory                   -0.0016      0.001     -2.063      0.039      -0.003   -7.93e-05
# ==============================================================================
# Omnibus:                    43509.668   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            66518.642
# Skew:                           0.658   Prob(JB):                         0.00
# Kurtosis:                       4.165   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     9506.
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:19   Log-Likelihood:            -5.5294e+05
# No. Observations:              517000   AIC:                         1.106e+06
# Df Residuals:                  516944   BIC:                         1.107e+06
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             1.847e-14      0.001   1.88e-11      1.000      -0.002       0.002
# farmSize                             0.0124      0.001      9.613      0.000       0.010       0.015
# subsidy                              0.1697      0.001    173.053      0.000       0.168       0.172
# giniCoeff                            0.0046      0.001      4.207      0.000       0.002       0.007
# trustIndexMean                       0.0044      0.001      4.479      0.000       0.002       0.006
# carePatchMean                       -0.1198      0.001   -122.123      0.000      -0.122      -0.118
# careFarmerMean                       0.0630      0.001     64.248      0.000       0.061       0.065
# careOthersMean                       0.0298      0.001     30.363      0.000       0.028       0.032
# initialExperience                    0.0591      0.001     60.272      0.000       0.057       0.061
# nchPercent                           0.4201      0.001    428.126      0.000       0.418       0.422
# memory                               0.0102      0.001     10.382      0.000       0.008       0.012
# farmSize*subsidy                     0.0252      0.001     23.488      0.000       0.023       0.027
# farmSize*giniCoeff                  -0.0042      0.001     -3.247      0.001      -0.007      -0.002
# farmSize*trustIndexMean              0.0009      0.001      0.874      0.382      -0.001       0.003
# farmSize*carePatchMean              -0.0131      0.001    -12.249      0.000      -0.015      -0.011
# farmSize*careFarmerMean              0.0094      0.001      8.742      0.000       0.007       0.011
# farmSize*careOthersMean              0.0053      0.001      4.959      0.000       0.003       0.007
# farmSize*initialExperience          -0.0135      0.001    -12.537      0.000      -0.016      -0.011
# farmSize*nchPercent                 -0.0025      0.001     -2.278      0.023      -0.005      -0.000
# farmSize*memory                     -0.0028      0.001     -2.631      0.009      -0.005      -0.001
# subsidy*giniCoeff                   -0.0075      0.001     -6.958      0.000      -0.010      -0.005
# subsidy*trustIndexMean               0.0246      0.001     25.103      0.000       0.023       0.027
# subsidy*carePatchMean                0.1004      0.001    102.343      0.000       0.098       0.102
# subsidy*careFarmerMean              -0.0411      0.001    -41.864      0.000      -0.043      -0.039
# subsidy*careOthersMean              -0.0152      0.001    -15.517      0.000      -0.017      -0.013
# subsidy*initialExperience            0.2130      0.001    217.188      0.000       0.211       0.215
# subsidy*nchPercent                   0.2075      0.001    211.602      0.000       0.206       0.209
# subsidy*memory                      -0.0142      0.001    -14.473      0.000      -0.016      -0.012
# giniCoeff*trustIndexMean             0.0011      0.001      1.030      0.303      -0.001       0.003
# giniCoeff*carePatchMean              0.0063      0.001      5.906      0.000       0.004       0.008
# giniCoeff*careFarmerMean             0.0023      0.001      2.137      0.033       0.000       0.004
# giniCoeff*careOthersMean             0.0004      0.001      0.347      0.729      -0.002       0.002
# giniCoeff*initialExperience         -0.0013      0.001     -1.247      0.212      -0.003       0.001
# giniCoeff*nchPercent                -0.0010      0.001     -0.970      0.332      -0.003       0.001
# giniCoeff*memory                  7.182e-05      0.001      0.067      0.947      -0.002       0.002
# trustIndexMean*carePatchMean        -0.0107      0.001    -10.907      0.000      -0.013      -0.009
# trustIndexMean*careFarmerMean        0.0079      0.001      8.042      0.000       0.006       0.010
# trustIndexMean*careOthersMean        0.0045      0.001      4.588      0.000       0.003       0.006
# trustIndexMean*initialExperience     0.0026      0.001      2.602      0.009       0.001       0.004
# trustIndexMean*nchPercent           -0.0085      0.001     -8.710      0.000      -0.010      -0.007
# trustIndexMean*memory                0.0007      0.001      0.733      0.464      -0.001       0.003
# carePatchMean*careFarmerMean         0.0079      0.001      8.021      0.000       0.006       0.010
# carePatchMean*careOthersMean        -0.0017      0.001     -1.733      0.083      -0.004       0.000
# carePatchMean*initialExperience     -0.0560      0.001    -57.064      0.000      -0.058      -0.054
# carePatchMean*nchPercent            -0.0011      0.001     -1.150      0.250      -0.003       0.001
# carePatchMean*memory                 0.0093      0.001      9.467      0.000       0.007       0.011
# careFarmerMean*careOthersMean       -0.0151      0.001    -15.438      0.000      -0.017      -0.013
# careFarmerMean*initialExperience     0.0247      0.001     25.182      0.000       0.023       0.027
# careFarmerMean*nchPercent            0.0058      0.001      5.865      0.000       0.004       0.008
# careFarmerMean*memory               -0.0017      0.001     -1.738      0.082      -0.004       0.000
# careOthersMean*initialExperience     0.0030      0.001      3.038      0.002       0.001       0.005
# careOthersMean*nchPercent            0.0002      0.001      0.232      0.816      -0.002       0.002
# careOthersMean*memory               -0.0031      0.001     -3.109      0.002      -0.005      -0.001
# initialExperience*nchPercent        -0.4114      0.001   -419.224      0.000      -0.413      -0.409
# initialExperience*memory             0.0049      0.001      4.998      0.000       0.003       0.007
# nchPercent*memory                   -0.0051      0.001     -5.203      0.000      -0.007      -0.003
# ==============================================================================
# Omnibus:                    11874.596   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15627.635
# Skew:                           0.288   Prob(JB):                         0.00
# Kurtosis:                       3.628   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.331
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     4649.
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:20   Log-Likelihood:            -6.2971e+05
# No. Observations:              517000   AIC:                         1.260e+06
# Df Residuals:                  516944   BIC:                         1.260e+06
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              1.35e-15      0.001   1.19e-12      1.000      -0.002       0.002
# farmSize                             0.0353      0.002     23.480      0.000       0.032       0.038
# subsidy                              0.0648      0.001     56.976      0.000       0.063       0.067
# giniCoeff                            0.0135      0.001     10.659      0.000       0.011       0.016
# trustIndexMean                       0.0653      0.001     57.334      0.000       0.063       0.067
# carePatchMean                       -0.2707      0.001   -237.885      0.000      -0.273      -0.269
# careFarmerMean                       0.1826      0.001    160.397      0.000       0.180       0.185
# careOthersMean                       0.0327      0.001     28.765      0.000       0.031       0.035
# initialExperience                    0.1244      0.001    109.340      0.000       0.122       0.127
# nchPercent                           0.1169      0.001    102.707      0.000       0.115       0.119
# memory                               0.0201      0.001     17.681      0.000       0.018       0.022
# farmSize*subsidy                     0.0252      0.001     20.236      0.000       0.023       0.028
# farmSize*giniCoeff                   0.0008      0.001      0.538      0.590      -0.002       0.004
# farmSize*trustIndexMean             -0.0073      0.001     -5.857      0.000      -0.010      -0.005
# farmSize*carePatchMean               0.0172      0.001     13.831      0.000       0.015       0.020
# farmSize*careFarmerMean             -0.0069      0.001     -5.497      0.000      -0.009      -0.004
# farmSize*careOthersMean             -0.0010      0.001     -0.810      0.418      -0.003       0.001
# farmSize*initialExperience           0.0098      0.001      7.850      0.000       0.007       0.012
# farmSize*nchPercent                 -0.0174      0.001    -13.975      0.000      -0.020      -0.015
# farmSize*memory                     -0.0053      0.001     -4.251      0.000      -0.008      -0.003
# subsidy*giniCoeff                    0.0124      0.001      9.990      0.000       0.010       0.015
# subsidy*trustIndexMean               0.0219      0.001     19.215      0.000       0.020       0.024
# subsidy*carePatchMean                0.1769      0.001    155.453      0.000       0.175       0.179
# subsidy*careFarmerMean              -0.1058      0.001    -93.013      0.000      -0.108      -0.104
# subsidy*careOthersMean               0.0070      0.001      6.176      0.000       0.005       0.009
# subsidy*initialExperience            0.1833      0.001    161.089      0.000       0.181       0.186
# subsidy*nchPercent                   0.1007      0.001     88.528      0.000       0.099       0.103
# subsidy*memory                      -0.0192      0.001    -16.875      0.000      -0.021      -0.017
# giniCoeff*trustIndexMean            -0.0044      0.001     -3.525      0.000      -0.007      -0.002
# giniCoeff*carePatchMean              0.0060      0.001      4.858      0.000       0.004       0.008
# giniCoeff*careFarmerMean             0.0031      0.001      2.470      0.014       0.001       0.006
# giniCoeff*careOthersMean            -0.0008      0.001     -0.603      0.547      -0.003       0.002
# giniCoeff*initialExperience         -0.0067      0.001     -5.407      0.000      -0.009      -0.004
# giniCoeff*nchPercent                -0.0038      0.001     -3.083      0.002      -0.006      -0.001
# giniCoeff*memory                    -0.0028      0.001     -2.255      0.024      -0.005      -0.000
# trustIndexMean*carePatchMean        -0.0075      0.001     -6.617      0.000      -0.010      -0.005
# trustIndexMean*careFarmerMean        0.0063      0.001      5.561      0.000       0.004       0.009
# trustIndexMean*careOthersMean        0.0033      0.001      2.922      0.003       0.001       0.006
# trustIndexMean*initialExperience    -0.0226      0.001    -19.847      0.000      -0.025      -0.020
# trustIndexMean*nchPercent            0.0031      0.001      2.692      0.007       0.001       0.005
# trustIndexMean*memory                0.0002      0.001      0.168      0.866      -0.002       0.002
# carePatchMean*careFarmerMean         0.0209      0.001     18.381      0.000       0.019       0.023
# carePatchMean*careOthersMean         0.0114      0.001     10.048      0.000       0.009       0.014
# carePatchMean*initialExperience     -0.1029      0.001    -90.422      0.000      -0.105      -0.101
# carePatchMean*nchPercent             0.0409      0.001     35.929      0.000       0.039       0.043
# carePatchMean*memory                 0.0068      0.001      6.002      0.000       0.005       0.009
# careFarmerMean*careOthersMean       -0.0316      0.001    -27.723      0.000      -0.034      -0.029
# careFarmerMean*initialExperience     0.0312      0.001     27.390      0.000       0.029       0.033
# careFarmerMean*nchPercent           -0.0117      0.001    -10.249      0.000      -0.014      -0.009
# careFarmerMean*memory               -0.0009      0.001     -0.834      0.404      -0.003       0.001
# careOthersMean*initialExperience     0.0135      0.001     11.825      0.000       0.011       0.016
# careOthersMean*nchPercent           -0.0233      0.001    -20.504      0.000      -0.026      -0.021
# careOthersMean*memory               -0.0033      0.001     -2.882      0.004      -0.006      -0.001
# initialExperience*nchPercent        -0.2822      0.001   -247.849      0.000      -0.284      -0.280
# initialExperience*memory             0.0061      0.001      5.347      0.000       0.004       0.008
# nchPercent*memory                   -0.0058      0.001     -5.114      0.000      -0.008      -0.004
# ==============================================================================
# Omnibus:                    17431.034   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19881.128
# Skew:                           0.434   Prob(JB):                         0.00
# Kurtosis:                       3.413   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     7380.
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:21   Log-Likelihood:            -5.8379e+05
# No. Observations:              517000   AIC:                         1.168e+06
# Df Residuals:                  516944   BIC:                         1.168e+06
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                            -3.218e-14      0.001  -3.09e-11      1.000      -0.002       0.002
# farmSize                            -0.5580      0.001   -406.032      0.000      -0.561      -0.555
# subsidy                              0.0043      0.001      4.169      0.000       0.002       0.006
# giniCoeff                            0.3906      0.001    335.856      0.000       0.388       0.393
# trustIndexMean                      -0.0061      0.001     -5.849      0.000      -0.008      -0.004
# carePatchMean                       -0.0953      0.001    -91.466      0.000      -0.097      -0.093
# careFarmerMean                       0.0038      0.001      3.649      0.000       0.002       0.006
# careOthersMean                       0.0625      0.001     59.966      0.000       0.060       0.065
# initialExperience                   -0.0242      0.001    -23.269      0.000      -0.026      -0.022
# nchPercent                           0.0910      0.001     87.403      0.000       0.089       0.093
# memory                               0.0105      0.001     10.074      0.000       0.008       0.013
# farmSize*subsidy                    -0.0196      0.001    -17.210      0.000      -0.022      -0.017
# farmSize*giniCoeff                  -0.4328      0.001   -315.467      0.000      -0.435      -0.430
# farmSize*trustIndexMean             -0.0228      0.001    -19.977      0.000      -0.025      -0.021
# farmSize*carePatchMean               0.0238      0.001     20.907      0.000       0.022       0.026
# farmSize*careFarmerMean             -0.0009      0.001     -0.776      0.438      -0.003       0.001
# farmSize*careOthersMean             -0.0112      0.001     -9.799      0.000      -0.013      -0.009
# farmSize*initialExperience          -0.0142      0.001    -12.479      0.000      -0.016      -0.012
# farmSize*nchPercent                 -0.0343      0.001    -30.052      0.000      -0.037      -0.032
# farmSize*memory                      0.0025      0.001      2.223      0.026       0.000       0.005
# subsidy*giniCoeff                    0.0520      0.001     45.704      0.000       0.050       0.054
# subsidy*trustIndexMean               0.0110      0.001     10.523      0.000       0.009       0.013
# subsidy*carePatchMean                0.0491      0.001     47.116      0.000       0.047       0.051
# subsidy*careFarmerMean              -0.0158      0.001    -15.167      0.000      -0.018      -0.014
# subsidy*careOthersMean              -0.0073      0.001     -7.014      0.000      -0.009      -0.005
# subsidy*initialExperience           -0.0765      0.001    -73.516      0.000      -0.079      -0.074
# subsidy*nchPercent                   0.0095      0.001      9.077      0.000       0.007       0.011
# subsidy*memory                      -0.0024      0.001     -2.303      0.021      -0.004      -0.000
# giniCoeff*trustIndexMean             0.0063      0.001      5.554      0.000       0.004       0.009
# giniCoeff*carePatchMean             -0.0271      0.001    -23.788      0.000      -0.029      -0.025
# giniCoeff*careFarmerMean            -0.0030      0.001     -2.649      0.008      -0.005      -0.001
# giniCoeff*careOthersMean             0.0084      0.001      7.340      0.000       0.006       0.011
# giniCoeff*initialExperience         -0.0009      0.001     -0.813      0.416      -0.003       0.001
# giniCoeff*nchPercent                 0.0190      0.001     16.689      0.000       0.017       0.021
# giniCoeff*memory                     0.0029      0.001      2.520      0.012       0.001       0.005
# trustIndexMean*carePatchMean        -0.0040      0.001     -3.796      0.000      -0.006      -0.002
# trustIndexMean*careFarmerMean        0.0011      0.001      1.036      0.300      -0.001       0.003
# trustIndexMean*careOthersMean        0.0015      0.001      1.446      0.148      -0.001       0.004
# trustIndexMean*initialExperience    -0.0245      0.001    -23.565      0.000      -0.027      -0.023
# trustIndexMean*nchPercent           -0.0122      0.001    -11.673      0.000      -0.014      -0.010
# trustIndexMean*memory                0.0019      0.001      1.779      0.075      -0.000       0.004
# carePatchMean*careFarmerMean         0.0161      0.001     15.469      0.000       0.014       0.018
# carePatchMean*careOthersMean        -0.0113      0.001    -10.836      0.000      -0.013      -0.009
# carePatchMean*initialExperience      0.0354      0.001     33.998      0.000       0.033       0.037
# carePatchMean*nchPercent            -0.0098      0.001     -9.426      0.000      -0.012      -0.008
# carePatchMean*memory              6.051e-06      0.001      0.006      0.995      -0.002       0.002
# careFarmerMean*careOthersMean       -0.0137      0.001    -13.189      0.000      -0.016      -0.012
# careFarmerMean*initialExperience    -0.0200      0.001    -19.188      0.000      -0.022      -0.018
# careFarmerMean*nchPercent            0.0078      0.001      7.444      0.000       0.006       0.010
# careFarmerMean*memory               -0.0019      0.001     -1.821      0.069      -0.004       0.000
# careOthersMean*initialExperience    -0.0220      0.001    -21.120      0.000      -0.024      -0.020
# careOthersMean*nchPercent            0.0084      0.001      8.064      0.000       0.006       0.010
# careOthersMean*memory               -0.0005      0.001     -0.483      0.629      -0.003       0.002
# initialExperience*nchPercent        -0.0916      0.001    -87.949      0.000      -0.094      -0.090
# initialExperience*memory             0.0036      0.001      3.463      0.001       0.002       0.006
# nchPercent*memory                   -0.0025      0.001     -2.369      0.018      -0.005      -0.000
# ==============================================================================
# Omnibus:                    89895.772   Durbin-Watson:                   1.328
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           205989.900
# Skew:                           1.003   Prob(JB):                         0.00
# Kurtosis:                       5.354   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.661
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                 1.831e+04
# Date:                Sat, 22 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:35:22   Log-Likelihood:            -4.5410e+05
# No. Observations:              517000   AIC:                         9.083e+05
# Df Residuals:                  516944   BIC:                         9.089e+05
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                            -1.585e-13      0.001  -1.96e-10      1.000      -0.002       0.002
# farmSize                            -0.0144      0.001    -13.431      0.000      -0.016      -0.012
# subsidy                             -0.4847      0.001   -598.331      0.000      -0.486      -0.483
# giniCoeff                           -0.0039      0.001     -4.320      0.000      -0.006      -0.002
# trustIndexMean                      -0.0139      0.001    -17.163      0.000      -0.015      -0.012
# carePatchMean                        0.2581      0.001    318.545      0.000       0.257       0.260
# careFarmerMean                      -0.1172      0.001   -144.562      0.000      -0.119      -0.116
# careOthersMean                      -0.0722      0.001    -89.051      0.000      -0.074      -0.071
# initialExperience                    0.3471      0.001    428.357      0.000       0.346       0.349
# nchPercent                          -0.1073      0.001   -132.367      0.000      -0.109      -0.106
# memory                              -0.0177      0.001    -21.806      0.000      -0.019      -0.016
# farmSize*subsidy                    -0.0128      0.001    -14.468      0.000      -0.015      -0.011
# farmSize*giniCoeff                  -0.0018      0.001     -1.709      0.087      -0.004       0.000
# farmSize*trustIndexMean             -0.0012      0.001     -1.385      0.166      -0.003       0.001
# farmSize*carePatchMean               0.0130      0.001     14.620      0.000       0.011       0.015
# farmSize*careFarmerMean             -0.0143      0.001    -16.119      0.000      -0.016      -0.013
# farmSize*careOthersMean             -0.0033      0.001     -3.709      0.000      -0.005      -0.002
# farmSize*initialExperience           0.0054      0.001      6.049      0.000       0.004       0.007
# farmSize*nchPercent                  0.0075      0.001      8.422      0.000       0.006       0.009
# farmSize*memory                      0.0012      0.001      1.393      0.164      -0.001       0.003
# subsidy*giniCoeff                   -0.0077      0.001     -8.646      0.000      -0.009      -0.006
# subsidy*trustIndexMean              -0.0296      0.001    -36.496      0.000      -0.031      -0.028
# subsidy*carePatchMean               -0.1656      0.001   -204.385      0.000      -0.167      -0.164
# subsidy*careFarmerMean               0.0543      0.001     67.036      0.000       0.053       0.056
# subsidy*careOthersMean               0.0330      0.001     40.700      0.000       0.031       0.035
# subsidy*initialExperience           -0.3533      0.001   -436.186      0.000      -0.355      -0.352
# subsidy*nchPercent                  -0.0672      0.001    -83.003      0.000      -0.069      -0.066
# subsidy*memory                       0.0167      0.001     20.625      0.000       0.015       0.018
# giniCoeff*trustIndexMean            -0.0018      0.001     -2.017      0.044      -0.004   -5.06e-05
# giniCoeff*carePatchMean              0.0011      0.001      1.218      0.223      -0.001       0.003
# giniCoeff*careFarmerMean            -0.0073      0.001     -8.238      0.000      -0.009      -0.006
# giniCoeff*careOthersMean            -0.0002      0.001     -0.279      0.780      -0.002       0.001
# giniCoeff*initialExperience          0.0033      0.001      3.735      0.000       0.002       0.005
# giniCoeff*nchPercent                 0.0009      0.001      1.063      0.288      -0.001       0.003
# giniCoeff*memory                     0.0003      0.001      0.300      0.764      -0.001       0.002
# trustIndexMean*carePatchMean         0.0088      0.001     10.807      0.000       0.007       0.010
# trustIndexMean*careFarmerMean       -0.0087      0.001    -10.737      0.000      -0.010      -0.007
# trustIndexMean*careOthersMean       -0.0021      0.001     -2.615      0.009      -0.004      -0.001
# trustIndexMean*initialExperience     0.0144      0.001     17.714      0.000       0.013       0.016
# trustIndexMean*nchPercent            0.0021      0.001      2.551      0.011       0.000       0.004
# trustIndexMean*memory               -0.0025      0.001     -3.023      0.002      -0.004      -0.001
# carePatchMean*careFarmerMean        -0.0016      0.001     -2.018      0.044      -0.003   -4.68e-05
# carePatchMean*careOthersMean         0.0030      0.001      3.723      0.000       0.001       0.005
# carePatchMean*initialExperience      0.1387      0.001    171.066      0.000       0.137       0.140
# carePatchMean*nchPercent            -0.0136      0.001    -16.725      0.000      -0.015      -0.012
# carePatchMean*memory                -0.0075      0.001     -9.315      0.000      -0.009      -0.006
# careFarmerMean*careOthersMean        0.0297      0.001     36.637      0.000       0.028       0.031
# careFarmerMean*initialExperience    -0.0543      0.001    -67.038      0.000      -0.056      -0.053
# careFarmerMean*nchPercent            0.0039      0.001      4.838      0.000       0.002       0.006
# careFarmerMean*memory                0.0019      0.001      2.401      0.016       0.000       0.004
# careOthersMean*initialExperience    -0.0173      0.001    -21.408      0.000      -0.019      -0.016
# careOthersMean*nchPercent            0.0108      0.001     13.296      0.000       0.009       0.012
# careOthersMean*memory                0.0032      0.001      3.897      0.000       0.002       0.005
# initialExperience*nchPercent         0.1477      0.001    182.161      0.000       0.146       0.149
# initialExperience*memory            -0.0062      0.001     -7.590      0.000      -0.008      -0.005
# nchPercent*memory                    0.0034      0.001      4.153      0.000       0.002       0.005
# ==============================================================================
# Omnibus:                    15043.595   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23486.609
# Skew:                           0.287   Prob(JB):                         0.00
# Kurtosis:                       3.872   Cond. No.                         2.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for i in range(len(coeff_dfs)):
    print("\n", metrics_extended[i])
    print(coeff_dfs[i])
# Out:
#  Income Per Patch
#                                   Coefficient        P-value
# subsidy                              0.672735   0.000000e+00
# initialExperience                    0.286570   0.000000e+00
# nchPercent                           0.264440   0.000000e+00
# initialExperience*nchPercent        -0.264394   0.000000e+00
# subsidy*nchPercent                   0.140221   0.000000e+00
# carePatchMean                       -0.118356   0.000000e+00
# farmSize                             0.088418   0.000000e+00
# subsidy*carePatchMean                0.079547   0.000000e+00
# trustIndexMean                       0.071602   0.000000e+00
# careFarmerMean                       0.064167   0.000000e+00
# subsidy*careOthersMean              -0.034198   0.000000e+00
# giniCoeff                            0.026849  7.914413e-246
# trustIndexMean*initialExperience    -0.025976  2.033786e-286
# careOthersMean                       0.025027  3.680054e-266
# farmSize*subsidy                    -0.021952  2.387048e-172
# subsidy*initialExperience            0.021625  1.622961e-199
# subsidy*trustIndexMean               0.020434  2.348146e-178
# careFarmerMean*nchPercent            0.017846  2.147623e-136
# careFarmerMean*careOthersMean       -0.015815  1.420787e-107
# subsidy*careFarmerMean              -0.015715  2.392106e-106
# farmSize*giniCoeff                   0.014861   1.069492e-55
# careOthersMean*nchPercent            0.014656   1.296203e-92
# carePatchMean*nchPercent            -0.014352   6.642637e-89
# memory                              -0.014151   1.416053e-86
# farmSize*trustIndexMean              0.012414   3.575221e-56
# carePatchMean*careFarmerMean        -0.010867   8.416963e-52
# trustIndexMean*nchPercent            0.010203   7.319187e-46
# giniCoeff*initialExperience         -0.009529   8.005068e-34
# farmSize*carePatchMean               0.008113   5.030881e-25
# subsidy*memory                       0.007860   6.064425e-28
# careOthersMean*initialExperience    -0.006543   7.655329e-20
# careFarmerMean*initialExperience    -0.005687   2.333399e-15
# carePatchMean*memory                -0.004593   1.532195e-10
# carePatchMean*initialExperience     -0.004573   1.881291e-10
# giniCoeff*carePatchMean              0.004451   1.418568e-08
# farmSize*nchPercent                 -0.004232   7.457889e-08
# trustIndexMean*carePatchMean        -0.004185   5.503321e-09
# farmSize*careOthersMean             -0.003157   5.865923e-05
# trustIndexMean*careOthersMean        0.002966   3.594223e-05
# careOthersMean*memory                0.002801   9.516118e-05
# initialExperience*memory            -0.002394   8.487631e-04
# giniCoeff*memory                    -0.002214   4.841374e-03
# giniCoeff*careOthersMean            -0.001887   1.630327e-02
# farmSize*memory                     -0.001886   1.640804e-02
# trustIndexMean*careFarmerMean        0.001434   4.570216e-02
# carePatchMean*careOthersMean         0.001356   5.882499e-02
# subsidy*giniCoeff                   -0.001325   9.109984e-02
# careFarmerMean*memory                0.001317   6.647509e-02
#
#  Net Production Per Patch
#                                   Coefficient        P-value
# initialExperience                    0.401409   0.000000e+00
# initialExperience*nchPercent        -0.303743   0.000000e+00
# nchPercent                           0.299111   0.000000e+00
# subsidy*nchPercent                   0.189474   0.000000e+00
# carePatchMean                       -0.142862   0.000000e+00
# subsidy                             -0.124854   0.000000e+00
# farmSize                             0.107238   0.000000e+00
# trustIndexMean                       0.091166   0.000000e+00
# careFarmerMean                       0.076415   0.000000e+00
# subsidy*initialExperience           -0.038669  6.410144e-303
# careOthersMean                       0.037544  2.029033e-285
# giniCoeff                            0.034560  1.051678e-194
# trustIndexMean*initialExperience    -0.029097  2.682524e-172
# subsidy*trustIndexMean               0.028618  6.098952e-167
# careFarmerMean*careOthersMean       -0.022910  1.240914e-107
# subsidy*careFarmerMean               0.016814   6.502493e-59
# memory                              -0.015828   2.144044e-52
# farmSize*giniCoeff                   0.015814   7.123090e-31
# farmSize*carePatchMean               0.015119   2.450486e-40
# trustIndexMean*nchPercent            0.013985   2.855119e-41
# farmSize*trustIndexMean              0.013732   1.655866e-33
# subsidy*memory                       0.010818   2.131887e-25
# farmSize*nchPercent                 -0.010741   4.182753e-21
# giniCoeff*initialExperience         -0.010601   1.250024e-20
# careOthersMean*initialExperience    -0.009952   1.001622e-21
# carePatchMean*careFarmerMean        -0.009839   2.852407e-21
# careFarmerMean*nchPercent            0.009118   1.758529e-18
# carePatchMean*nchPercent             0.008943   7.764369e-18
# carePatchMean*careOthersMean         0.007910   2.715487e-14
# subsidy*carePatchMean                0.007402   1.039053e-12
# giniCoeff*carePatchMean              0.006592   6.637980e-09
# farmSize*subsidy                    -0.006322   2.586109e-08
# subsidy*careOthersMean               0.006266   1.622985e-09
# farmSize*careFarmerMean             -0.005971   1.543738e-07
# carePatchMean*memory                -0.005577   8.004235e-08
# careFarmerMean*initialExperience    -0.005343   2.756808e-07
# trustIndexMean*carePatchMean        -0.005338   2.798993e-07
# farmSize*careOthersMean             -0.005295   3.263676e-06
# subsidy*giniCoeff                    0.003879   6.355084e-04
# careOthersMean*memory                0.003487   7.958504e-04
# carePatchMean*initialExperience     -0.003390   1.110646e-03
# farmSize*memory                     -0.003066   7.049996e-03
# giniCoeff*careFarmerMean            -0.002899   1.087174e-02
# giniCoeff*memory                    -0.002775   1.476293e-02
# trustIndexMean*careOthersMean        0.002448   1.853664e-02
# giniCoeff*careOthersMean            -0.002396   3.516602e-02
#
#  NCH Patches
#                                   Coefficient        P-value
# subsidy                              0.746925   0.000000e+00
# subsidy*carePatchMean                0.209092   0.000000e+00
# initialExperience                   -0.153244   0.000000e+00
# carePatchMean                       -0.139903   0.000000e+00
# subsidy*initialExperience            0.123511   0.000000e+00
# subsidy*careOthersMean              -0.081884   0.000000e+00
# nchPercent                           0.079663   0.000000e+00
# initialExperience*nchPercent        -0.078761   0.000000e+00
# subsidy*careFarmerMean              -0.070182   0.000000e+00
# careFarmerMean                       0.050473   0.000000e+00
# subsidy*nchPercent                  -0.043951   0.000000e+00
# farmSize*subsidy                    -0.043464   0.000000e+00
# careOthersMean                       0.041082   0.000000e+00
# farmSize                             0.035240  3.430648e-265
# carePatchMean*nchPercent            -0.033039   0.000000e+00
# careOthersMean*nchPercent            0.027201  9.125423e-275
# farmSize*careFarmerMean              0.017821  8.421322e-100
# careFarmerMean*nchPercent            0.017245  8.867105e-112
# carePatchMean*careOthersMean        -0.016671  1.238220e-104
# careOthersMean*initialExperience    -0.016618  5.573408e-104
# farmSize*carePatchMean              -0.015092   3.132494e-72
# subsidy*giniCoeff                   -0.011331   1.307344e-41
# carePatchMean*initialExperience      0.011215   2.383615e-48
# careFarmerMean*careOthersMean       -0.010578   3.165344e-43
# careFarmerMean*initialExperience    -0.010233   1.509411e-40
# farmSize*giniCoeff                   0.009686   9.361699e-22
# farmSize*nchPercent                  0.007237   7.697759e-18
# giniCoeff*careFarmerMean             0.007009   7.501930e-17
# carePatchMean*careFarmerMean        -0.005767   5.667054e-14
# trustIndexMean*initialExperience    -0.004307   2.001329e-08
# giniCoeff                            0.004299   5.252650e-07
# initialExperience*memory            -0.003575   3.180307e-06
# subsidy*trustIndexMean              -0.003096   5.428152e-05
# giniCoeff*initialExperience         -0.002769   9.838312e-04
# trustIndexMean*careFarmerMean        0.002531   9.728585e-04
# memory                              -0.002341   2.279033e-03
# farmSize*trustIndexMean              0.002289   6.457175e-03
# farmSize*initialExperience          -0.002274   6.833299e-03
# farmSize*careOthersMean              0.001999   1.735403e-02
# giniCoeff*carePatchMean             -0.001940   2.077007e-02
# giniCoeff*nchPercent                 0.001896   2.410342e-02
# nchPercent*memory                   -0.001583   3.908672e-02
# subsidy*memory                      -0.001412   6.561297e-02
# trustIndexMean*nchPercent           -0.001370   7.426428e-02
# trustIndexMean*memory                0.001294   9.170503e-02
#
#  Non-HS Strategy Adoption
#                                   Coefficient        P-value
# nchPercent                           0.420116   0.000000e+00
# initialExperience*nchPercent        -0.411394   0.000000e+00
# subsidy*initialExperience            0.213007   0.000000e+00
# subsidy*nchPercent                   0.207545   0.000000e+00
# subsidy                              0.169709   0.000000e+00
# carePatchMean                       -0.119813   0.000000e+00
# subsidy*carePatchMean                0.100375   0.000000e+00
# careFarmerMean                       0.063035   0.000000e+00
# initialExperience                    0.059128   0.000000e+00
# carePatchMean*initialExperience     -0.056003   0.000000e+00
# subsidy*careFarmerMean              -0.041059   0.000000e+00
# careOthersMean                       0.029793  2.561796e-202
# farmSize*subsidy                     0.025182  6.216529e-122
# careFarmerMean*initialExperience     0.024716  7.676735e-140
# subsidy*trustIndexMean               0.024621  5.655979e-139
# subsidy*careOthersMean              -0.015219   2.749170e-54
# careFarmerMean*careOthersMean       -0.015149   9.305270e-54
# subsidy*memory                      -0.014194   1.826748e-47
# farmSize*initialExperience          -0.013478   4.715644e-36
# farmSize*carePatchMean              -0.013150   1.722720e-34
# farmSize                             0.012444   7.095720e-22
# trustIndexMean*carePatchMean        -0.010703   1.073763e-27
# memory                               0.010184   3.006338e-25
# farmSize*careFarmerMean              0.009393   2.296011e-18
# carePatchMean*memory                 0.009287   2.896492e-21
# trustIndexMean*nchPercent           -0.008547   3.039581e-18
# trustIndexMean*careFarmerMean        0.007892   8.891213e-16
# carePatchMean*careFarmerMean         0.007870   1.049954e-15
# subsidy*giniCoeff                   -0.007460   3.467040e-12
# giniCoeff*carePatchMean              0.006339   3.501744e-09
# careFarmerMean*nchPercent            0.005755   4.498379e-09
# farmSize*careOthersMean              0.005327   7.089906e-07
# nchPercent*memory                   -0.005105   1.964691e-07
# initialExperience*memory             0.004905   5.790363e-07
# giniCoeff                            0.004609   2.591719e-05
# trustIndexMean*careOthersMean        0.004504   4.468925e-06
# trustIndexMean                       0.004395   7.501752e-06
# farmSize*giniCoeff                  -0.004196   1.167247e-03
# careOthersMean*memory               -0.003051   1.877854e-03
# careOthersMean*initialExperience     0.002981   2.383678e-03
# farmSize*memory                     -0.002827   8.509576e-03
# trustIndexMean*initialExperience     0.002553   9.280587e-03
# farmSize*nchPercent                 -0.002450   2.274276e-02
# giniCoeff*careFarmerMean             0.002297   3.258455e-02
# careFarmerMean*memory               -0.001706   8.217873e-02
# carePatchMean*careOthersMean        -0.001701   8.305914e-02
#
#  Production Benefit Per NCH Patch
#                                   Coefficient        P-value
# initialExperience*nchPercent        -0.282156   0.000000e+00
# carePatchMean                       -0.270750   0.000000e+00
# subsidy*initialExperience            0.183281   0.000000e+00
# careFarmerMean                       0.182563   0.000000e+00
# subsidy*carePatchMean                0.176873   0.000000e+00
# initialExperience                    0.124435   0.000000e+00
# nchPercent                           0.116920   0.000000e+00
# subsidy*careFarmerMean              -0.105830   0.000000e+00
# carePatchMean*initialExperience     -0.102948   0.000000e+00
# subsidy*nchPercent                   0.100732   0.000000e+00
# trustIndexMean                       0.065266   0.000000e+00
# subsidy                              0.064820   0.000000e+00
# carePatchMean*nchPercent             0.040908  2.425661e-282
# farmSize                             0.035264  7.495929e-122
# careOthersMean                       0.032744  8.242520e-182
# careFarmerMean*careOthersMean       -0.031559  4.859642e-169
# careFarmerMean*initialExperience     0.031187  4.725509e-165
# farmSize*subsidy                     0.025169   5.072061e-91
# careOthersMean*nchPercent           -0.023346   2.177316e-93
# trustIndexMean*initialExperience    -0.022597   1.268578e-87
# subsidy*trustIndexMean               0.021863   2.979908e-82
# carePatchMean*careFarmerMean         0.020922   1.965379e-75
# memory                               0.020121   6.150924e-70
# subsidy*memory                      -0.019199   7.200846e-64
# farmSize*nchPercent                 -0.017439   2.253501e-44
# farmSize*carePatchMean               0.017225   1.692990e-43
# giniCoeff                            0.013550   1.588556e-26
# careOthersMean*initialExperience     0.013460   2.919873e-32
# subsidy*giniCoeff                    0.012426   1.691795e-23
# careFarmerMean*nchPercent           -0.011668   1.202703e-24
# carePatchMean*careOthersMean         0.011437   9.449418e-24
# farmSize*initialExperience           0.009790   4.164433e-15
# trustIndexMean*carePatchMean        -0.007533   3.659594e-11
# farmSize*trustIndexMean             -0.007303   4.710258e-09
# subsidy*careOthersMean               0.007028   6.561634e-10
# farmSize*careFarmerMean             -0.006852   3.866352e-08
# carePatchMean*memory                 0.006830   1.953210e-09
# giniCoeff*initialExperience         -0.006742   6.411535e-08
# trustIndexMean*careFarmerMean        0.006332   2.678000e-08
# initialExperience*memory             0.006087   8.934233e-08
# giniCoeff*carePatchMean              0.006048   1.186844e-06
# nchPercent*memory                   -0.005821   3.161326e-07
# farmSize*memory                     -0.005299   2.125310e-05
# giniCoeff*trustIndexMean            -0.004391   4.242719e-04
# giniCoeff*nchPercent                -0.003845   2.046118e-03
# trustIndexMean*careOthersMean        0.003327   3.477638e-03
# careOthersMean*memory               -0.003282   3.948340e-03
# giniCoeff*careFarmerMean             0.003080   1.351221e-02
# trustIndexMean*nchPercent            0.003064   7.102055e-03
# giniCoeff*memory                    -0.002812   2.410749e-02
#
#  Income Deviation
#                                   Coefficient        P-value
# farmSize                            -0.557961   0.000000e+00
# farmSize*giniCoeff                  -0.432750   0.000000e+00
# giniCoeff                            0.390640   0.000000e+00
# carePatchMean                       -0.095254   0.000000e+00
# initialExperience*nchPercent        -0.091613   0.000000e+00
# nchPercent                           0.091042   0.000000e+00
# subsidy*initialExperience           -0.076534   0.000000e+00
# careOthersMean                       0.062459   0.000000e+00
# subsidy*giniCoeff                    0.052015   0.000000e+00
# subsidy*carePatchMean                0.049052   0.000000e+00
# carePatchMean*initialExperience      0.035417  4.596277e-253
# farmSize*nchPercent                 -0.034312  3.061516e-198
# giniCoeff*carePatchMean             -0.027099  5.200872e-125
# trustIndexMean*initialExperience    -0.024550  1.017399e-122
# initialExperience                   -0.024231  1.055838e-119
# farmSize*carePatchMean               0.023825   5.083992e-97
# farmSize*trustIndexMean             -0.022791   9.348556e-89
# careOthersMean*initialExperience    -0.021997   5.687718e-99
# careFarmerMean*initialExperience    -0.019991   4.995586e-82
# farmSize*subsidy                    -0.019585   2.338917e-66
# giniCoeff*nchPercent                 0.019044   1.641636e-62
# carePatchMean*careFarmerMean         0.016111   5.792571e-54
# subsidy*careFarmerMean              -0.015790   6.014767e-52
# farmSize*initialExperience          -0.014241   9.787840e-36
# careFarmerMean*careOthersMean       -0.013738   1.028146e-39
# trustIndexMean*nchPercent           -0.012158   1.768371e-31
# carePatchMean*careOthersMean        -0.011285   2.343230e-27
# farmSize*careOthersMean             -0.011174   1.144099e-22
# subsidy*trustIndexMean               0.010955   6.841619e-26
# memory                               0.010489   7.255661e-24
# carePatchMean*nchPercent            -0.009820   4.264076e-21
# subsidy*nchPercent                   0.009451   1.118801e-19
# careOthersMean*nchPercent            0.008402   7.382293e-16
# giniCoeff*careOthersMean             0.008370   2.131662e-13
# careFarmerMean*nchPercent            0.007755   9.747479e-14
# subsidy*careOthersMean              -0.007302   2.319473e-12
# giniCoeff*trustIndexMean             0.006332   2.789441e-08
# trustIndexMean                      -0.006092   4.954332e-09
# subsidy                              0.004340   3.054399e-05
# trustIndexMean*carePatchMean        -0.003954   1.467796e-04
# careFarmerMean                       0.003800   2.637161e-04
# initialExperience*memory             0.003607   5.344565e-04
# giniCoeff*careFarmerMean            -0.003022   8.069305e-03
# giniCoeff*memory                     0.002875   1.171913e-02
# farmSize*memory                      0.002536   2.618431e-02
# nchPercent*memory                   -0.002468   1.783079e-02
# subsidy*memory                      -0.002397   2.129442e-02
# careFarmerMean*memory               -0.001896   6.866626e-02
# trustIndexMean*memory                0.001853   7.522374e-02
#
#  HS Patches
#                                   Coefficient        P-value
# subsidy                             -0.484660   0.000000e+00
# subsidy*initialExperience           -0.353345   0.000000e+00
# initialExperience                    0.347095   0.000000e+00
# carePatchMean                        0.258136   0.000000e+00
# subsidy*carePatchMean               -0.165572   0.000000e+00
# initialExperience*nchPercent         0.147651   0.000000e+00
# carePatchMean*initialExperience      0.138670   0.000000e+00
# careFarmerMean                      -0.117151   0.000000e+00
# nchPercent                          -0.107287   0.000000e+00
# careOthersMean                      -0.072175   0.000000e+00
# subsidy*nchPercent                  -0.067245   0.000000e+00
# careFarmerMean*initialExperience    -0.054348   0.000000e+00
# subsidy*careFarmerMean               0.054306   0.000000e+00
# subsidy*careOthersMean               0.032973   0.000000e+00
# careFarmerMean*careOthersMean        0.029694  1.784448e-293
# subsidy*trustIndexMean              -0.029567  3.000187e-291
# memory                              -0.017668  2.268104e-105
# careOthersMean*initialExperience    -0.017350  1.237514e-101
# subsidy*memory                       0.016707   1.797528e-94
# farmSize                            -0.014361   4.059833e-41
# trustIndexMean*initialExperience     0.014360   3.421301e-70
# farmSize*careFarmerMean             -0.014305   1.944565e-58
# trustIndexMean                      -0.013911   5.243867e-66
# carePatchMean*nchPercent            -0.013558   8.941637e-63
# farmSize*carePatchMean               0.012964   2.151338e-48
# farmSize*subsidy                    -0.012812   1.961203e-47
# careOthersMean*nchPercent            0.010779   2.475207e-40
# trustIndexMean*carePatchMean         0.008759   3.210485e-27
# trustIndexMean*careFarmerMean       -0.008704   6.862161e-27
# subsidy*giniCoeff                   -0.007657   5.333563e-18
# carePatchMean*memory                -0.007548   1.221136e-20
# farmSize*nchPercent                  0.007482   3.717184e-17
# giniCoeff*careFarmerMean            -0.007313   1.756650e-16
# initialExperience*memory            -0.006152   3.202329e-14
# farmSize*initialExperience           0.005372   1.455300e-09
# careFarmerMean*nchPercent            0.003922   1.310252e-06
# giniCoeff                           -0.003910   1.561766e-05
# nchPercent*memory                    0.003366   3.276277e-05
# giniCoeff*initialExperience          0.003316   1.877736e-04
# farmSize*careOthersMean             -0.003291   2.082740e-04
# careOthersMean*memory                0.003159   9.735923e-05
# carePatchMean*careOthersMean         0.003017   1.968199e-04
# trustIndexMean*memory               -0.002450   2.499514e-03
# trustIndexMean*careOthersMean       -0.002120   8.932125e-03
# trustIndexMean*nchPercent            0.002068   1.072876e-02
# careFarmerMean*memory                0.001946   1.636491e-02
# farmSize*giniCoeff                  -0.001825   8.737090e-02
# giniCoeff*trustIndexMean            -0.001789   4.369609e-02
# carePatchMean*careFarmerMean        -0.001635   4.362397e-02

# %%
for i in range(len(coeff_dfs)):
    coeff_dfs[i].to_csv(os.path.join(directory, sensitivity_folder, sensitivity_results, metrics_extended[i]+".csv"))

# %%
param_dict=dict()
for parameter in parameters_df.columns:
    param_dict[parameter]=pd.DataFrame(columns=['Coefficient', 'P-value'])
    for i in range(len(coeff_dfs)):
        for row in coeff_dfs[i].index:
            if parameter in row:
                temp=row+', '+metrics_extended[i]
                param_dict[parameter].loc[temp]=coeff_dfs[i].loc[row]
    param_dict[parameter].sort_values(by='Coefficient', key=abs, inplace=True, ascending=False)

# %%
for col in param_dict.keys():
    param_dict[col].to_csv(os.path.join(directory, sensitivity_folder, sensitivity_results+"_metrics", col+".csv"))
